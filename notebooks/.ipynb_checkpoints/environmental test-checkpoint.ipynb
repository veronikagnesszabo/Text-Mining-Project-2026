# %%
import nltk
import spacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nrclex import NRCLex
print("nltk installed successfully")
print("spacy installed successfully")
print("vaderSentiment installed successfully")
print("nrclex installed successfully")
print("Environment setup complete")
# Out:
# nltk installed successfully
# spacy installed successfully
# vaderSentiment installed successfully
# nrclex installed successfully
# Environment setup complete
